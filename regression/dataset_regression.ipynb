# %% [markdown]
# # Построение линии регрессии
#
# **Датасет:** -
# **Задача:** предсказание непрерывной переменной с помощью линейной регрессии

# %% [markdown]
# ## 1. Краткая теория
#
# **Линейная регрессия** ищет линейную функцию y = w₀ + w₁x₁ + ... + wₙxₙ, минимизируя MSE. Аналитическое решение - нормальное уравнение: w = (XᵀX)⁻¹Xᵀy. Подробная теория - в [README.md](README.md).

# %% [markdown]
# ## 2. Загрузка данных

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
# TODO: загрузить датасет

# %% [markdown]
# ## 3. Первичный анализ

# %%
# TODO: df.describe(), распределения признаков, корреляции

# %% [markdown]
# ## 4. Предобработка

# %%
# TODO: очистка, масштабирование, разбиение на train/test

# %% [markdown]
# ## 5. Обучение модели

# %%
# TODO: baseline модель + подбор гиперпараметров

# %% [markdown]
# ## 6. Оценка качества

# %%
# TODO: метрики и визуализация результатов
