# %% [markdown]
# # Mean Shift
#
# **Датасет:** -
# **Задача:** кластеризация методом Mean Shift

# %% [markdown]
# ## 1. Краткая теория
#
# **Mean Shift** - алгоритм кластеризации на основе плотности. Итеративно сдвигает точки к локальным максимумам плотности (модам). Число кластеров определяется автоматически, ключевой параметр - bandwidth. Подробная теория - в [README.md](README.md).

# %% [markdown]
# ## 2. Загрузка данных

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.preprocessing import StandardScaler

# %%
# TODO: загрузить датасет

# %% [markdown]
# ## 3. Первичный анализ

# %%
# TODO: df.describe(), распределения признаков, корреляции

# %% [markdown]
# ## 4. Предобработка

# %%
# TODO: очистка, масштабирование, разбиение на train/test

# %% [markdown]
# ## 5. Обучение модели

# %%
# TODO: baseline модель + подбор гиперпараметров

# %% [markdown]
# ## 6. Оценка качества

# %%
# TODO: метрики и визуализация результатов
