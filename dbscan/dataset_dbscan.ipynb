# %% [markdown]
# # DBSCAN
#
# **Датасет:** -
# **Задача:** кластеризация методом DBSCAN

# %% [markdown]
# ## 1. Краткая теория
#
# **DBSCAN** группирует точки по плотности: ядровые точки (>= min_samples соседей в радиусе eps) формируют кластеры, остальные - шум. Не требует указания числа кластеров, устойчив к выбросам. Подробная теория - в [README.md](README.md).

# %% [markdown]
# ## 2. Загрузка данных

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

# %%
# TODO: загрузить датасет

# %% [markdown]
# ## 3. Первичный анализ

# %%
# TODO: df.describe(), распределения признаков, корреляции

# %% [markdown]
# ## 4. Предобработка

# %%
# TODO: очистка, масштабирование, разбиение на train/test

# %% [markdown]
# ## 5. Обучение модели

# %%
# TODO: baseline модель + подбор гиперпараметров

# %% [markdown]
# ## 6. Оценка качества

# %%
# TODO: метрики и визуализация результатов
