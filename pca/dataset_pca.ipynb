# %% [markdown]
# # Метод главных компонент (PCA)
#
# **Датасет:** —
# **Задача:** снижение размерности и визуализация данных

# %% [markdown]
# ## 1. Краткая теория
#
# **PCA** проецирует данные на ортогональные оси максимальной дисперсии (главные компоненты) через собственное разложение ковариационной матрицы. Стандартизация данных обязательна. Подробная теория — в [README.md](README.md).

# %% [markdown]
# ## 2. Загрузка данных

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# TODO: загрузить датасет

# %% [markdown]
# ## 3. Первичный анализ

# %%
# TODO: df.describe(), распределения признаков, корреляции

# %% [markdown]
# ## 4. Предобработка

# %%
# TODO: очистка, масштабирование, разбиение на train/test

# %% [markdown]
# ## 5. Обучение модели

# %%
# TODO: baseline модель + подбор гиперпараметров

# %% [markdown]
# ## 6. Оценка качества

# %%
# TODO: метрики и визуализация результатов
