# %% [markdown]
# # Классификационное дерево и Random Forest
#
# **Датасет:** -
# **Задача:** классификация с помощью дерева решений и Random Forest

# %% [markdown]
# ## 1. Краткая теория
#
# **Дерево решений** рекурсивно разбивает пространство признаков, используя критерий Gini или энтропию. **Random Forest** - ансамбль деревьев с бэггингом и случайными подмножествами признаков. Подробная теория - в [README.md](README.md).

# %% [markdown]
# ## 2. Загрузка данных

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# TODO: загрузить датасет

# %% [markdown]
# ## 3. Первичный анализ

# %%
# TODO: df.describe(), распределения признаков, корреляции

# %% [markdown]
# ## 4. Предобработка

# %%
# TODO: очистка, масштабирование, разбиение на train/test

# %% [markdown]
# ## 5. Обучение модели

# %%
# TODO: baseline модель + подбор гиперпараметров

# %% [markdown]
# ## 6. Оценка качества

# %%
# TODO: метрики и визуализация результатов
