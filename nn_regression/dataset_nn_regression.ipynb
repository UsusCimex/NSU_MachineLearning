# %% [markdown]
# # Нейронная сеть прямого распространения - регрессия
#
# **Датасет:** -
# **Задача:** регрессия с помощью feedforward нейросети

# %% [markdown]
# ## 1. Краткая теория
#
# **Feedforward нейросеть** для регрессии: архитектура аналогична классификации, но выходной слой - один нейрон без активации (линейный выход), функция потерь - MSE. Подробная теория - в [README.md](README.md).

# %% [markdown]
# ## 2. Загрузка данных

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %%
# TODO: загрузить датасет

# %% [markdown]
# ## 3. Первичный анализ

# %%
# TODO: df.describe(), распределения признаков, корреляции

# %% [markdown]
# ## 4. Предобработка

# %%
# TODO: очистка, масштабирование, разбиение на train/test

# %% [markdown]
# ## 5. Обучение модели

# %%
# TODO: baseline модель + подбор гиперпараметров

# %% [markdown]
# ## 6. Оценка качества

# %%
# TODO: метрики и визуализация результатов
