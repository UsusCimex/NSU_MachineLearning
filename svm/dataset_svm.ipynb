# %% [markdown]
# # Машины опорных векторов (SVM)
#
# **Датасет:** —
# **Задача:** классификация с помощью SVM

# %% [markdown]
# ## 1. Краткая теория
#
# **SVM** ищет гиперплоскость с максимальным зазором между классами. Для нелинейных данных используется ядерный трюк (RBF, polynomial). Параметр C контролирует компромисс между шириной зазора и ошибками. Подробная теория — в [README.md](README.md).

# %% [markdown]
# ## 2. Загрузка данных

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler

# %%
# TODO: загрузить датасет

# %% [markdown]
# ## 3. Первичный анализ

# %%
# TODO: df.describe(), распределения признаков, корреляции

# %% [markdown]
# ## 4. Предобработка

# %%
# TODO: очистка, масштабирование, разбиение на train/test

# %% [markdown]
# ## 5. Обучение модели

# %%
# TODO: baseline модель + подбор гиперпараметров

# %% [markdown]
# ## 6. Оценка качества

# %%
# TODO: метрики и визуализация результатов
